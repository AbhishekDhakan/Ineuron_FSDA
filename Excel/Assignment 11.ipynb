# %% [markdown]
# Using this data for answering all questions below
#
# ![question  1.png](attachment:31966849-1abd-4a2d-b3e2-09e823d51a1a.png)

# %% [markdown]
# Q1. Find the Minimum Marks and Maximum marks scored by each student ?
#
# Ans ->
#
# ![ans 1.png](attachment:dfbb3f19-3230-4d3b-98f5-a4c73e272bd9.png)

# %% [markdown]
# Q2. Calculate the totals for each student, use conditional formatting to highlight the top students who have scored more than 480.
#
# Ans ->
#
# ![ans 2.png](attachment:a14789f4-99bf-49f9-96be-47c52bb55319.png)

# %% [markdown]
# Q3. Calculate the length of the names of each student ?
#
# Ans ->
#
# ![ans 3.png](attachment:a372c42e-2414-4616-b261-b1444fc2783b.png)

# %% [markdown]
# Q4. Replace the Name Rakhi with Rocky. Use Formulas ?
#
# Ans ->
#
# ![ans 4.png](attachment:f54f0c72-46bb-46eb-a7e9-eb7ce554a22c.png)

# %% [markdown]
# Q5. Combine the Roll Numbers and Names. Use formulas. The end result should look like below.
# 100101Rohan
#
# Ans ->
#
# ![ans 5.png](attachment:c9d67220-8a90-406a-b7ee-5a97912c2cb5.png)

# %% [markdown]
# Q6. As you can see that some names have spacing issues. Use Formulas to correct that spacing. Also ensure that the names and surnames start with a capital letter ?
#
# Ans ->
#
# ![ans 6.png](attachment:990970fa-2170-4089-8132-528365d069c8.png)
