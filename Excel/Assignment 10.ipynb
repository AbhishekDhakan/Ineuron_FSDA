# %% [markdown]
# Q1. See the below picture and create the exact table with exact formatting.
# Font – ‘Times New Roman’ Size – 14, Color of first line Orange.
#
# ![question 1.png](attachment:896133f6-cc87-4a49-9426-a33d43390a30.png)

# %% [markdown]
# Ans ->
#
# ![ans 1.png](attachment:1cc7d1ad-d546-4128-837b-1c194f433c14.png)

# %% [markdown]
# Q2. From the above table use Sum Formula and find the total for each student ?
#
# Ans ->
#
# ![ans 2.png](attachment:68dd0dd3-8c2a-4a10-8168-ccacf68c57e4.png)

# %% [markdown]
# Q3. Calculate Average for each student in the next row. Use Formulas ?
#
# Ans ->
#
# ![ans 3.png](attachment:8f3d85a3-8da9-405a-b89d-499afe36d823.png)

# %% [markdown]
# Q4. Calculate Rank for each student. Use Formulas ?
#
# Ans ->
#
# ![ans 4.png](attachment:2856edd8-85a7-4df4-b456-df1973264968.png)

# %% [markdown]
# Q5. Calculate Percentage for each student. Use Formulas. Round off the decimals up to 2 points ?
#
# Ans ->
#
# ![ans 5.png](attachment:52b59f9c-8bd8-4df2-a838-c9ae90b4ce31.png)
